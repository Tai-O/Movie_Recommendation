# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics import jaccard_score

import pickle
import scipy

# %%
data=pd.read_excel("movie_data.xlsx")
data.info()
data.rename(columns={'Unnamed: 0': 'movie_id'}, inplace=True)
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Year of Release     999 non-null    object
#  3   Watch Time          952 non-null    object
#  4   Genre               1000 non-null   object
#  5   Movie Rating        943 non-null    float64
#  6   Metascore of movie  909 non-null    float64
#  7   Director            1000 non-null   object
#  8   Cast                1000 non-null   object
#  9   Votes               943 non-null    object
#  10  Description         1000 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 86.1+ KB
#    movie_id                        Title Year of Release Watch Time  \
# 0         0               No Time to Die            2021    163 min
# 1         1                         Dune            2021    155 min
# 2         2                     Free Guy            2021    115 min
# 3         3    The Many Saints of Newark            2021    120 min
# 4         4  Venom: Let There Be Carnage            2021     97 min
#
#                                        Genre  Movie Rating  \
# 0  \nAction, Adventure, Thriller                       7.7
# 1     \nAction, Adventure, Drama                       8.4
# 2    \nAction, Adventure, Comedy                       7.3
# 3                 \nCrime, Drama                       6.6
# 4    \nAction, Adventure, Sci-Fi                       6.6
#
#    Metascore of movie            Director  \
# 0                70.0  Cary Joji Fukunaga
# 1                76.0    Denis Villeneuve
# 2                62.0          Shawn Levy
# 3                61.0         Alan Taylor
# 4                47.0         Andy Serkis
#
#                                                 Cast    Votes  \
# 0   Daniel Craig,Ana de Armas,Rami Malek,Léa Seydoux   35,153
# 1  Timothée Chalamet,Rebecca Ferguson,Zendaya,Osc...   63,210
# 2  Ryan Reynolds,Jodie Comer,Taika Waititi,Lil Re...  117,171
# 3  Alessandro Nivola,Leslie Odom Jr.,Jon Bernthal...   15,173
# 4  Tom Hardy,Woody Harrelson,Michelle Williams,Na...   10,107
#
#                                          Description
# 0  James Bond has left active service. His peace ...
# 1  Feature adaptation of Frank Herbert's science ...
# 2  A bank teller discovers that he's actually an ...
# 3  A look at the formative years of New Jersey ga...
# 4  Eddie Brock attempts to reignite his career by...

# %%
columns=['Cast','Director','Genre','Title','Description']
columns2=['Cast','Director','Genre','Title', 'Movie Rating','Description']
columns3=['Cast','Director','Genre','Title','Metascore of movie','Description']

# %%
data[columns].isnull().values.any()#no null values
# Out:
# False

# %%
def get_important_features(data):
    important_features=[]
    for i in range (0,data.shape[0]):
        important_features.append(data['Title'][i]+' '+data['Director'][i]+' '+data['Genre'][i]+' '+data['Description'][i])
    return important_features

# %%
#creating a column to hold the combined strings
data['important_features']=get_important_features(data)

tfidf = TfidfVectorizer(stop_words='english')
feature_matrix = tfidf.fit_transform(data['important_features'])
feature_matrix.shape
# Out:
# (1000, 6709)

# %%
# Movie Similarity Checker
cosine_sim = linear_kernel(feature_matrix, feature_matrix)

# %%
indices = pd.Series(data.index, index=data['Title']).drop_duplicates()

def get_recommendations(title, cosine_sim=cosine_sim):
    idx = indices[title]
    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the movies based on the similarity score
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:6]
    movie_indices = [i[0] for i in sim_scores]
    
    # Return the top 5 most similar movies
    movies=data['Title'].iloc[movie_indices]
    id=data['movie_id'].iloc[movie_indices]
    dict={"Movies":movies,"id":id}
    final_df=pd.DataFrame(dict)
    final_df.reset_index(drop=True,inplace=True)
    return final_df

# %%
# Test Movie Recommendation - Cosine
get_recommendations('Venom: Let There Be Carnage')
# Out:
#                                             Movies   id
# 0                                            Venom   20
# 1                         The Silence of the Lambs  196
# 2                             Escape from New York  919
# 3  Birdman or (The Unexpected Virtue of Ignorance)  892
# 4                                       Let Him Go  450

# %%
# Test Movie Recommendation - Cosine
get_recommendations('Spider-Man: Far from Home')
# Out:
#                               Movies   id
# 0            Spider-Man: No Way Home   36
# 1             Spider-Man: Homecoming  227
# 2  Spider-Man: Into the Spider-Verse  233
# 3           The Amazing Spider-Man 2  500
# 4                         Spider-Man  138

# %%
# Test Movie Recommendation - Cosine
get_recommendations('Reservoir Dogs')
# Out:
#               Movies   id
# 0     No Sudden Move  346
# 1        The Descent  783
# 2  Kill Bill: Vol. 1  440
# 3  The Hateful Eight  433
# 4       Pulp Fiction  112

# %%
data.info()
new = data.drop(columns=['Year of Release','Watch Time','Genre','Movie Rating','Metascore of movie','Director','Cast','Votes','Description'])

pickle.dump(new,open('movie_list.pkl','wb'))
pickle.dump(cosine_sim,open('similarity.pkl','wb'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movie_id            1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Year of Release     999 non-null    object
#  3   Watch Time          952 non-null    object
#  4   Genre               1000 non-null   object
#  5   Movie Rating        943 non-null    float64
#  6   Metascore of movie  909 non-null    float64
#  7   Director            1000 non-null   object
#  8   Cast                1000 non-null   object
#  9   Votes               943 non-null    object
#  10  Description         1000 non-null   object
#  11  important_features  1000 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.9+ KB

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-0.89.0-py2.py3-none-any.whl (8.3 MB)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: watchdog in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (1.0.2)
# Collecting protobuf!=3.11,>=3.6.0
#   Downloading protobuf-3.18.0-cp38-cp38-win_amd64.whl (912 kB)
# Requirement already satisfied: toml in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: python-dateutil in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (2.8.1)
# Collecting altair>=3.2.0
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
# Collecting base58
#   Downloading base58-2.1.0-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: attrs in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (20.3.0)
# Requirement already satisfied: requests in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (2.25.1)
# Requirement already satisfied: packaging in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (20.9)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (1.2.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (8.2.0)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.0-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: click<8.0,>=7.0 in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (7.1.2)
# Collecting cachetools>=4.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Requirement already satisfied: numpy in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (1.20.1)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting tzlocal
#   Downloading tzlocal-3.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: tornado>=5.0 in c:\users\tottun\anaconda3\lib\site-packages (from streamlit) (6.1)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
# Collecting pyarrow
#   Downloading pyarrow-5.0.0-cp38-cp38-win_amd64.whl (14.5 MB)
# Requirement already satisfied: entrypoints in c:\users\tottun\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: jsonschema in c:\users\tottun\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: jinja2 in c:\users\tottun\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: toolz in c:\users\tottun\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tottun\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (3.7.4.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tottun\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.1)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\tottun\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\tottun\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\tottun\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\tottun\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.22.0)
# Requirement already satisfied: jupyter-client in c:\users\tottun\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in c:\users\tottun\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.17.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\tottun\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (52.0.0.post20210125)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\tottun\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.17)
# Requirement already satisfied: pygments in c:\users\tottun\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.8.1)
# Requirement already satisfied: backcall in c:\users\tottun\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\tottun\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: colorama in c:\users\tottun\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: decorator in c:\users\tottun\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.0.6)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\tottun\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\tottun\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\tottun\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\tottun\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tottun\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: jupyter-core in c:\users\tottun\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: ipython-genutils in c:\users\tottun\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\tottun\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\tottun\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (1.15.0)
# Requirement already satisfied: wcwidth in c:\users\tottun\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\tottun\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.3.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\tottun\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.0.0)
# Requirement already satisfied: argon2-cffi in c:\users\tottun\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\tottun\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\tottun\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\tottun\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\users\tottun\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.10.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\tottun\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\tottun\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\tottun\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\tottun\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: defusedxml in c:\users\tottun\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: bleach in c:\users\tottun\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\tottun\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\tottun\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: testpath in c:\users\tottun\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\tottun\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\tottun\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.3)
# Requirement already satisfied: async-generator in c:\users\tottun\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\tottun\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\tottun\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\tottun\anaconda3\lib\site-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\tottun\anaconda3\lib\site-packages (from requests->streamlit) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tottun\anaconda3\lib\site-packages (from requests->streamlit) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\tottun\anaconda3\lib\site-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tottun\anaconda3\lib\site-packages (from requests->streamlit) (2020.12.5)
# Collecting tzdata
#   Downloading tzdata-2021.2.post0-py2.py3-none-any.whl (339 kB)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13451 sha256=f5f9977b99a45aaac0297c5b3b614a71c57efa7ed789c7b424c9399d1de0080e
#   Stored in directory: c:\users\tottun\appdata\local\pip\cache\wheels\b7\a5\68\fe632054a5eadd531c7a49d740c50eb6adfbeca822b4eab8d4
# Successfully built blinker
# Installing collected packages: smmap, tzdata, gitdb, backports.zoneinfo, validators, tzlocal, pydeck, pyarrow, protobuf, gitpython, cachetools, blinker, base58, astor, altair, streamlit
# Successfully installed altair-4.1.0 astor-0.8.1 backports.zoneinfo-0.2.1 base58-2.1.0 blinker-1.4 cachetools-4.2.4 gitdb-4.0.7 gitpython-3.1.24 protobuf-3.18.0 pyarrow-5.0.0 pydeck-0.7.0 smmap-4.0.0 streamlit-0.89.0 tzdata-2021.2.post0 tzlocal-3.0 validators-0.18.2
